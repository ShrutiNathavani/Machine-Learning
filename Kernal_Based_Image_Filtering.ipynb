# %%
import cv2
import numpy as np
import  matplotlib.pyplot as plt
from PIL import Image,ImageFilter
import pandas as pd
from scipy.ndimage.filters import convolve
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_15132\3511168453.py:6: DeprecationWarning: Please use `convolve` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import convolve

# %%
# converting gray scale image
path = "/content/ItachiUchiha.jpeg"
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\ICT 2020-2021\SEM 5\ML\Kernal\Kernal_Based_Image_Filtering.ipynb Cell 2 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/e%3A/ICT%202020-2021/SEM%205/ML/Kernal/Kernal_Based_Image_Filtering.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> path = "/content/ItachiUchiha.jpeg"
#       <a href='vscode-notebook-cell:/e%3A/ICT%202020-2021/SEM%205/ML/Kernal/Kernal_Based_Image_Filtering.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
# ----> <a href='vscode-notebook-cell:/e%3A/ICT%202020-2021/SEM%205/ML/Kernal/Kernal_Based_Image_Filtering.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> cv2.im.show(img)
#       <a href='vscode-notebook-cell:/e%3A/ICT%202020-2021/SEM%205/ML/Kernal/Kernal_Based_Image_Filtering.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> cv2.waitKey(0)
#
# AttributeError: module 'cv2' has no attribute 'im'

# %%
# apply various kernels
identity = np.array([[0,0,0], [0,1,0], [0,0,0]])
edgedetection = ([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
top_sobel = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]])
sharpen = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
emboss =  np.array([[-2, -1, 0], [-1,  1, 1], [ 0,  1, 2]])
gaussian = (1 / 256.0) * np.array([[1, 4, 6, 4, 1], [4, 16, 24, 16, 4], [6, 24, 36, 24, 6], [4, 16, 24, 16, 4], [1, 4, 6, 4, 1]])
smallBlur = np.ones((7, 7), dtype="float") * (1.0/(10))
horizontal = np.array([[-1, -1, -1], [2, 2, 2], [-1, -1, -1]])
vertical = np.array([[-1, 2, -1], [-1, 2, -1], [-1, 2, -1]])

# %%
kernels = [identity, edgedetection, top_sobel, sharpen, emboss, gaussian, smallBlur, horizontal, vertical]
k_name = ['Identity', 'Edgedetection', 'Top_sobel', 'Sharpen', 'Emboss', 'Gaussian', 'SmallBlur', 'Horizontal', 'Vertical']

im = np.array(img, dtype=float)

for i in range(len(kernels)):
    kernel = kernels[i];
    name = k_name[i];

    # kernel = kernels[0]
    im2 = convolve(im, kernel)
    img3 = np.array(np.clip(im2,0,255), dtype=np.uint8)

    img_new = cv2.hconcat([img3])
    print(name)
    cv2_imshow(img_new)
    print("\n")
    cv2.waitKey(0)
# Out:
# Identity
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A372EE850>
# Edgedetection
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A373B2D90>
# Top_sobel
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F050>
# Sharpen
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6FA90>
# Emboss
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F050>
# Gaussian
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F050>
# SmallBlur
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F050>
# Horizontal
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F050>
# Vertical
# <PIL.Image.Image image mode=L size=199x253 at 0x7F1A37F6F550>
